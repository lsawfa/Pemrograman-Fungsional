# %% [markdown]
# **Nama: Larynt Sawfa Kenanga**
#
# **NIM: 202110370311189**
#
# **Kelas: Prak. Fungsio A**

# %% [markdown]
# # Perhitungan Transformasi

# %% [markdown]
# *Catatan:*
# $$
# [x,y,z] \rightarrow [1,8,9]
# $$
# $$
# A [x,y] \rightarrow A [1,8]
# $$
# $$
# M = x \rightarrow M = 1
# $$
# $$
# tx = y \rightarrow tx = 8
# $$
# $$
# ty = z \rightarrow ty = 9
# $$
# $$
# sx = z \rightarrow sx = 9
# $$
# $$
# sy = x \rightarrow sy = 1
# $$

# %% [markdown]
# ## Persamaan Garis Sebelum Transformasi
#
# \[ y = mx + c \]
#
#    \[ 8 = (1) (1) + c \]
#
#    \[ 8 = 1 + c \]
#
#    \[ c = 8 - 1\]
#
#    \[ c = 7 \]
#
#    \[ y = x + 7 \]
#
#    Jadi persamaan garis setelah transformasi adalah
#    $$
#    y = x + 7
#    $$

# %% [markdown]
# ## Diketahui
# - Titik A = (1,8)
# - Gradien (m) = 1
# - Koordinat translasi (tx, ty) = (8,9)
# - Sudut rotasi = 60 derajat
# - Koordinat dilatasi (sx,sy) = (9,1)

# %% [markdown]
# ## Ditanya
# Persamaan garis setelah transformasi

# %% [markdown]
# ## Jawab
#
# 1. Titik A (1,8) ditranslasi terhadap (8,9)
#
#     $$
#     \begin{bmatrix}
#     x' \\
#     y'
#     \end{bmatrix}
#     =
#     \begin{bmatrix}
#     x + t_x \\
#     y + t_y
#     \end{bmatrix}
#     $$
#
#     $$
#     \begin{bmatrix}
#     x' \\
#     y'
#     \end{bmatrix}
#     =
#     \begin{bmatrix}
#     1 + 8 \\
#     8 + 9
#     \end{bmatrix}
#     $$
#
#     $$
#     \begin{bmatrix}
#     x' \\
#     y'
#     \end{bmatrix}
#     =
#     \begin{bmatrix}
#     9 \\
#     17
#     \end{bmatrix}
#     $$
#
#     Jadi A' = (9,17)

# %% [markdown]
# 2. Titik A' (9,17) rotasi sejajar sumbu x positif sebesar 60 derajat
#
#     $$
#     \begin{bmatrix}
#     x' \\
#     y'
#     \end{bmatrix}
#     \overset{\text{Rotasi 60°}}{\longleftarrow}
#     \begin{bmatrix}
#     x \\
#     y
#     \end{bmatrix}
#     $$
#
#
#     $$
#     \begin{bmatrix}
#     x' \\
#     y'
#     \end{bmatrix}
#     =
#     \begin{bmatrix}
#     \cos(60^\circ) & -\sin(60^\circ) \\
#     \sin(60^\circ) & \cos(60^\circ)
#     \end{bmatrix}
#     \begin{bmatrix}
#     x \\
#     y
#     \end{bmatrix}
#     $$
#
#     $$
#     \begin{align*}
#     x' &= x \cos(60^\circ) - y \sin(60^\circ) \\
#     y' &= x \sin(60^\circ) + y \cos(60^\circ)
#     \end{align*}
#     $$
#
#     $$
#     \begin{align*}
#     x' &= 9 \cos(60^\circ) - 17 \sin(60^\circ) \\
#     y' &= 9 \sin(60^\circ) + 17 \cos(60^\circ)
#     \end{align*}
#     $$
#
#     $$
#     \begin{align*}
#     x' &= 9 (\frac{1}{2}) - 17 (\frac{1}{2} \sqrt{3}) \\
#     y' &= 9 (\frac{1}{2} \sqrt{3}) + 17 (\frac{1}{2})
#     \end{align*}
#     $$
#
#     $$
#     \begin{align*}
#     x' &= \frac{9}{2} - \frac{17}{2} \sqrt{3} \\
#     y' &= \frac{9}{2} \sqrt{3} + \frac{17}{2}
#     \end{align*}
#     $$
#
#     $$
#     \begin{align*}
#     x' &= \frac{9-17\sqrt{3}}{2} \\
#     y' &= \frac{9\sqrt{3}+17}{2}
#     \end{align*}
#     $$
#
#     $$
#     \begin{align*}
#     x' &= -10.22243 \\
#     y' &= 16.29423
#     \end{align*}
#     $$
#
#     Jadi A'' = (-10.22243, 16.29423)

# %% [markdown]
# 3. Titik A'' = (-10.22243, 16.29423) dilatasi dengan koordinat (9, 1)
#
#     $$
#     \begin{align*}
#     x' &= s_x \cdot x \\
#     y' &= s_y \cdot y
#     \end{align*}
#     $$
#
#     $$
#     \begin{align*}
#     x' &= 9 \cdot -10.22243 \\
#     y' &= 1 \cdot 16.29423
#     \end{align*}
#     $$
#
#     $$
#     \begin{align*}
#     x' &= -92.00189 \\
#     y' &= 16.29423
#     \end{align*}
#     $$
#
#     Jadi A''' = (-92.00189, 16.29423)

# %% [markdown]
# 4. Persamaan garis A''' = (-92.00189, 16.29423) dengan gradient 1
#
#    \[ y = mx + c \]
#
#    \[ 16.29423 = (-92.00189) (1) + c \]
#
#    \[ 16.29423 = -92.00189 + c \]
#
#    \[ c = 92.00189 + 16.29423\]
#
#    \[ c = 108.29612 \]
#
#    \[ y = x + 108.29612 \]
#
#    Jadi persamaan garis setelah transformasi adalah
#    $$
#    y = x + 108.29612
#    $$
